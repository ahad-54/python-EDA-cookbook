# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **CSV File**

# %%
data = pd.read_csv('carsdata.csv')
data.head()
# Out:
#      Maker  Genmodel  Genmodel_ID   Adv_ID  Adv_year  Adv_month   Color  \
# 0  Bentley    Arnage         10_1  10_1$$1    2018.0        4.0  Silver
# 1  Bentley    Arnage         10_1  10_1$$2    2018.0        6.0    Grey
# 2  Bentley    Arnage         10_1  10_1$$3    2017.0       11.0    Blue
# 3  Bentley    Arnage         10_1  10_1$$4    2018.0        4.0   Green
# 4  Bentley    Arnage         10_1  10_1$$5    2017.0       11.0    Grey
#
#    Reg_year Bodytype  Runned_Miles  ... Engine_power Annual_Tax Wheelbase  \
# 0    2000.0   Saloon       60000.0  ...          NaN        NaN    3116.0
# 1    2002.0   Saloon       44000.0  ...        450.0        315    3116.0
# 2    2002.0   Saloon       55000.0  ...        400.0        315    3116.0
# 3    2003.0   Saloon       14000.0  ...          NaN        NaN    3116.0
# 4    2003.0   Saloon       61652.0  ...          NaN        NaN    3116.0
#
#    Height   Width  Length  Average_mpg  Top_speed  Seat_num  Door_num
# 0  1515.0  2125.0  5390.0          NaN        NaN       5.0       4.0
# 1  1515.0  2125.0  5390.0     13.7 mpg    179 mph       5.0       4.0
# 2  1515.0  2125.0  5390.0     14.7 mpg    155 mph       5.0       4.0
# 3  1515.0  2125.0  5390.0          NaN        NaN       5.0       4.0
# 4  1515.0  2125.0  5390.0          NaN        NaN       5.0       4.0
#
# [5 rows x 24 columns]

# %% [markdown]
# # **Subset For Relative columns**

# %%
cd = data [['Maker','Reg_year',	'Adv_month','Color','Runned_Miles','Wheelbase','Length','Top_speed','Seat_num','Average_mpg']]
cd.head(10)
# Out:
#      Maker  Reg_year  Adv_month   Color  Runned_Miles  Wheelbase  Length  \
# 0  Bentley    2000.0        4.0  Silver       60000.0     3116.0  5390.0
# 1  Bentley    2002.0        6.0    Grey       44000.0     3116.0  5390.0
# 2  Bentley    2002.0       11.0    Blue       55000.0     3116.0  5390.0
# 3  Bentley    2003.0        4.0   Green       14000.0     3116.0  5390.0
# 4  Bentley    2003.0       11.0    Grey       61652.0     3116.0  5390.0
# 5  Bentley    2002.0       12.0    Blue       55000.0     3116.0  5390.0
# 6  Bentley    2002.0        8.0   Green       67000.0     3116.0  5390.0
# 7  Bentley    2003.0        4.0   Black       99200.0     3116.0  5390.0
# 8  Bentley    2003.0        2.0  Silver       27541.0     3116.0  5390.0
# 9  Bentley    2003.0       11.0  Silver       38000.0     3116.0  5390.0
#
#   Top_speed  Seat_num Average_mpg
# 0       NaN       5.0         NaN
# 1   179 mph       5.0    13.7 mpg
# 2   155 mph       5.0    14.7 mpg
# 3       NaN       5.0         NaN
# 4       NaN       5.0         NaN
# 5   179 mph       5.0    13.7 mpg
# 6   179 mph       5.0    13.7 mpg
# 7       NaN       5.0         NaN
# 8       NaN       4.0         NaN
# 9       NaN       5.0         NaN

# %%
cd.head()
# Out:
#      Maker  Reg_year  Adv_month   Color  Runned_Miles  Wheelbase  Length  \
# 0  Bentley    2000.0        4.0  Silver       60000.0     3116.0  5390.0
# 1  Bentley    2002.0        6.0    Grey       44000.0     3116.0  5390.0
# 2  Bentley    2002.0       11.0    Blue       55000.0     3116.0  5390.0
# 3  Bentley    2003.0        4.0   Green       14000.0     3116.0  5390.0
# 4  Bentley    2003.0       11.0    Grey       61652.0     3116.0  5390.0
#
#   Top_speed  Seat_num Average_mpg
# 0       NaN       5.0         NaN
# 1   179 mph       5.0    13.7 mpg
# 2   155 mph       5.0    14.7 mpg
# 3       NaN       5.0         NaN
# 4       NaN       5.0         NaN

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516 entries, 0 to 515
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Maker         514 non-null    object
#  1   Reg_year      514 non-null    float64
#  2   Adv_month     514 non-null    float64
#  3   Color         493 non-null    object
#  4   Runned_Miles  512 non-null    float64
#  5   Wheelbase     463 non-null    float64
#  6   Length        463 non-null    float64
#  7   Top_speed     241 non-null    object
#  8   Seat_num      491 non-null    float64
#  9   Average_mpg   230 non-null    object
# dtypes: float64(6), object(4)
# memory usage: 40.4+ KB

# %%
cd.dtypes
# Out:
# Maker            object
# Reg_year        float64
# Adv_month       float64
# Color            object
# Runned_Miles    float64
# Wheelbase       float64
# Length          float64
# Top_speed        object
# Seat_num        float64
# Average_mpg      object
# dtype: object

# %%
cd.shape
# Out:
# (516, 10)

# %%
cd.columns = cd.columns.str.strip().str.replace(' ', '_')
#we use this if our data in file have empty spaces it add underscroll between them
print(cd.columns.tolist())
# Out:
# ['Maker', 'Reg_year', 'Adv_month', 'Color', 'Runned_Miles', 'Wheelbase', 'Length', 'Top_speed', 'Seat_num', 'Average_mpg']

# %% [markdown]
# **Checking the Runned Miles of cars based on registration year**

# %%
cd.groupby('Reg_year')['Runned_Miles'].mean()
# Out:
# Reg_year
# 1995.0    89577.200000
# 2000.0    59205.500000
# 2002.0    53331.333333
# 2003.0    60807.333333
# 2004.0    64626.868421
# 2005.0    67542.411765
# 2008.0    49510.566667
# 2009.0    42811.368421
# 2010.0    34141.636364
# 2011.0    33155.230769
# 2012.0    32024.064516
# 2013.0    22275.538462
# 2014.0    19415.954545
# 2015.0    21531.500000
# 2016.0    12727.869565
# 2017.0     7509.229167
# 2018.0     1765.000000
# 2019.0    13562.272727
# Name: Runned_Miles, dtype: float64

# %% [markdown]
# # **Average Number of cars Per color**
# The average number of cars per color means how many cars have same color. It shows which color cars are more popular among customers. A higher average indicates a popular car color, while a lower average shows less demand for that colored cars.
#
# Means it tells us the mean number of cars for each car.
#
# For example, if:
#
# Color A had 50 cars,
#
# Color B had 20 cars,
#
# Color C had 30 cars, then the average cars per color = (50 + 20 + 30) ÷ 3 = 33.3 pickups.
#
# It tells how popular a color of car is on average. The higher the number, the more popular the colo is for cars.
#
# # **Why we used it**
# Identify the more popular colors among customers.
#
# Resource Allocation like the company can produce more cars to high-demand color cars.

# %%
cars_percolor = cd['Color'].value_counts()
print("No. of cars with different colors:")
print(cars_percolor)
average_carcolor = cars_percolor.mean()
print(f"Average number of cars per color: {average_carcolor:.2f}")
# Out:
# No. of cars with different colors:
# Color
# Black     146
# Grey      106
# Blue       84
# Silver     73
# White      45
# Green      17
# Red        14
# Brown       3
# Orange      2
# Purple      2
# Maroon      1
# Name: count, dtype: int64
# Average number of cars per color: 44.82

# %% [markdown]
# # **Importing CSV file again for new functions**

# %%
cd1 = pd.read_csv("carsdata.csv")
cd1.head()
# Out:
#      Maker  Genmodel  Genmodel_ID   Adv_ID  Adv_year  Adv_month   Color  \
# 0  Bentley    Arnage         10_1  10_1$$1    2018.0        4.0  Silver
# 1  Bentley    Arnage         10_1  10_1$$2    2018.0        6.0    Grey
# 2  Bentley    Arnage         10_1  10_1$$3    2017.0       11.0    Blue
# 3  Bentley    Arnage         10_1  10_1$$4    2018.0        4.0   Green
# 4  Bentley    Arnage         10_1  10_1$$5    2017.0       11.0    Grey
#
#    Reg_year Bodytype  Runned_Miles  ... Engine_power Annual_Tax Wheelbase  \
# 0    2000.0   Saloon       60000.0  ...          NaN        NaN    3116.0
# 1    2002.0   Saloon       44000.0  ...        450.0        315    3116.0
# 2    2002.0   Saloon       55000.0  ...        400.0        315    3116.0
# 3    2003.0   Saloon       14000.0  ...          NaN        NaN    3116.0
# 4    2003.0   Saloon       61652.0  ...          NaN        NaN    3116.0
#
#    Height   Width  Length  Average_mpg  Top_speed  Seat_num  Door_num
# 0  1515.0  2125.0  5390.0          NaN        NaN       5.0       4.0
# 1  1515.0  2125.0  5390.0     13.7 mpg    179 mph       5.0       4.0
# 2  1515.0  2125.0  5390.0     14.7 mpg    155 mph       5.0       4.0
# 3  1515.0  2125.0  5390.0          NaN        NaN       5.0       4.0
# 4  1515.0  2125.0  5390.0          NaN        NaN       5.0       4.0
#
# [5 rows x 24 columns]

# %%
cd2 = pd.read_csv("carsdata2.csv")
cd2.tail()
# Out:
#      Citroen   C4 Cactus  18_13  18_13$$332  2018  5   White  2014 Hatchback  \
# 352  Citroen  C4 Picasso  18_14  18_14$$215  2018  7    Grey  2008       MPV
# 353  Citroen  C4 Picasso  18_14  18_14$$216  2018  4  Silver  2007       MPV
# 354  Citroen  C4 Picasso  18_14  18_14$$217  2018  7   White  2016       MPV
# 355  Citroen  C4 Picasso  18_14  18_14$$218  2018  6    Grey  2017       MPV
# 356  Citroen  C4 Picasso  18_14  18_14$$219  2018  4     Red  2017       MPV
#
#         35000  ...      91      0    2595    1540    1946    4157  80.7 mpg  \
# 352   87000.0  ...  110.00    155  2728.0  1680.0  1830.0  4590.0  49.6 mpg
# 353  130000.0  ...  110.00    155  2728.0  1680.0  1830.0  4590.0  54.3 mpg
# 354    6519.0  ...  118.00     20  2785.0  1610.0  1826.0  4428.0  78.5 mpg
# 355   16733.0  ...  118.00   140*  2785.0  1625.0  2117.0  4438.0  74.3 mpg
# 356   13800.0  ...   98.63      0  2785.0  1625.0  2117.0  4438.0  74.3 mpg
#
#      109 mph  5.1  5.2
# 352  112 mph  5.0  5.0
# 353  112 mph  7.0  5.0
# 354  117 mph  5.0  5.0
# 355  117 mph  5.0  5.0
# 356  109 mph  5.0  5.0
#
# [5 rows x 24 columns]

# %%
cd1.shape
# Out:
# (516, 24)

# %%
cd2.shape
# Out:
# (357, 24)

# %% [markdown]
# # **Appending**:
# Appending means adding more rows (new data) to our existing dataset (DataFrame).
#
# It does not replace data, it just extends it.
#
# Appending in my dataset means adding new cars data rows (trips) to the existing file so that you have one combined dataset for analysis.
#
# Appending use only for adding the rows.
#
# for Example:-
# Suppose in my dataset df has these columns:Maker	Genmodel	Genmodel_ID	Adv_ID	Adv_year	Adv_month	Color	Reg_year	Bodytype	Runned_Miles	...	Engine_power	Annual_Tax	Wheelbase	Height	Width	Length	Average_mpg	Top_speed	Seat_num	Door_num
#
#
# If i get new cars records from the next day or another source,i can append them to the existing dataset.
#
# # **Why we use Appending?**
# We use appending for update dataset with new cars data.
#
# To combine multiple CSVs into one dataset.
#
# To grow dataset for analysis (trends, averages, prediction).

# %%
appended_data = pd.concat([cd1, cd2])

# %%
appended_data.shape
# Out:
# (873, 48)

# %%
appended_data.head()
# Out:
#      Maker  Genmodel  Genmodel_ID   Adv_ID  Adv_year  Adv_month   Color  \
# 0  Bentley    Arnage         10_1  10_1$$1    2018.0        4.0  Silver
# 1  Bentley    Arnage         10_1  10_1$$2    2018.0        6.0    Grey
# 2  Bentley    Arnage         10_1  10_1$$3    2017.0       11.0    Blue
# 3  Bentley    Arnage         10_1  10_1$$4    2018.0        4.0   Green
# 4  Bentley    Arnage         10_1  10_1$$5    2017.0       11.0    Grey
#
#    Reg_year Bodytype  Runned_Miles  ...  91    0 2595  1540  1946 4157  \
# 0    2000.0   Saloon       60000.0  ... NaN  NaN  NaN   NaN   NaN  NaN
# 1    2002.0   Saloon       44000.0  ... NaN  NaN  NaN   NaN   NaN  NaN
# 2    2002.0   Saloon       55000.0  ... NaN  NaN  NaN   NaN   NaN  NaN
# 3    2003.0   Saloon       14000.0  ... NaN  NaN  NaN   NaN   NaN  NaN
# 4    2003.0   Saloon       61652.0  ... NaN  NaN  NaN   NaN   NaN  NaN
#
#    80.7 mpg  109 mph  5.1  5.2
# 0       NaN      NaN  NaN  NaN
# 1       NaN      NaN  NaN  NaN
# 2       NaN      NaN  NaN  NaN
# 3       NaN      NaN  NaN  NaN
# 4       NaN      NaN  NaN  NaN
#
# [5 rows x 48 columns]

# %% [markdown]
# # **Concatenating**:
# Concatenation in Pandas means joining two or more datasets together.
#
# By default it stacks them row-wise (one below another like appending).
#
# But it can also work column-wise (side by side) if needed.
#
# According to my dataset:-
# # **According to my dataset:-**
#
# If i have cars data from Day 1 and Day 2, concatenation combines them into one dataset (row-wise).
#
# And if i have different information about the same rides in separate files (e.g, one file has cars details another has payment info) concatenation can also join them column-wise.
#
# Concatenation means joining datasets either row by row or column by column.
#
# In my ride carsdata dataset it is used to combine multiple days rides (rows) or to add new attributes (columns) to the same cars data.

# %%
carsdata1 = pd.read_csv("carsdata.csv")
carsdata2 = pd.read_csv("carsdata2.csv")

# %%
concatenated_data = pd.concat([carsdata1, carsdata2], axis = 1)

# %%
concatenated_data.shape
# Out:
# (516, 48)

# %% [markdown]
# # **Merging**
# Merging means joining two datasets (tables) together using a common column (like an ID). It’s like matching rows from both tables where the key values are the same. This helps bring related information into one table.
#
# For example; In my data set i joins both left and right index because in my datasets i-e carsdata and carsdata2, in both datasets has no similar column, so thats why
# I am mergimg the index's.

# %%
merged_data = pd.merge(carsdata1,carsdata2, left_index=True, right_index=True)
merged_data.head()
# Out:
#      Maker  Genmodel  Genmodel_ID   Adv_ID  Adv_year  Adv_month   Color  \
# 0  Bentley    Arnage         10_1  10_1$$1    2018.0        4.0  Silver
# 1  Bentley    Arnage         10_1  10_1$$2    2018.0        6.0    Grey
# 2  Bentley    Arnage         10_1  10_1$$3    2017.0       11.0    Blue
# 3  Bentley    Arnage         10_1  10_1$$4    2018.0        4.0   Green
# 4  Bentley    Arnage         10_1  10_1$$5    2017.0       11.0    Grey
#
#    Reg_year Bodytype  Runned_Miles  ...     91      0    2595    1540    1946  \
# 0    2000.0   Saloon       60000.0  ...  81.00     20  2595.0  1540.0  1946.0
# 1    2002.0   Saloon       44000.0  ...    NaN      0     NaN     NaN     NaN
# 2    2002.0   Saloon       55000.0  ...  98.63      0  2595.0  1540.0  1946.0
# 3    2003.0   Saloon       14000.0  ...  91.00      0  2595.0  1540.0  1946.0
# 4    2003.0   Saloon       61652.0  ...  99.00   140*  2595.0  1480.0  1729.0
#
#      4157  80.7 mpg  109 mph  5.1  5.2
# 0  4157.0  61.4 mpg  106 mph  5.0  5.0
# 1     NaN       NaN      NaN  5.0  NaN
# 2  4157.0  83.1 mpg  114 mph  5.0  5.0
# 3  4157.0  80.7 mpg  109 mph  5.0  5.0
# 4  4157.0  80.7 mpg  114 mph  5.0  5.0
#
# [5 rows x 48 columns]

# %%
merged_data.shape
# Out:
# (357, 48)

# %% [markdown]
# # **Sorting**:
# Sorting means arranging data in a particular order so it becomes organized and easy to understand.
#
# It can be ascending order (smallest to largest A to Z) or descending order (largest to smallest Z to A).
#
# Sorting organizes information to make it easier to read, compare, and analyze.
#
# # **Logic Behind This Code:-**
#  In my dataset it help us to understand sorting the cars registered year based on theirmaker from earliest to longest (ascending=False). After sorting it only shows the Reg_year and Maker columns.

# %%
cd = data [['Maker','Reg_year',	'Adv_month','Color','Runned_Miles','Wheelbase','Length','Top_speed','Seat_num','Average_mpg']]
cd.head()
# Out:
#      Maker  Reg_year  Adv_month   Color  Runned_Miles  Wheelbase  Length  \
# 0  Bentley    2000.0        4.0  Silver       60000.0     3116.0  5390.0
# 1  Bentley    2002.0        6.0    Grey       44000.0     3116.0  5390.0
# 2  Bentley    2002.0       11.0    Blue       55000.0     3116.0  5390.0
# 3  Bentley    2003.0        4.0   Green       14000.0     3116.0  5390.0
# 4  Bentley    2003.0       11.0    Grey       61652.0     3116.0  5390.0
#
#   Top_speed  Seat_num Average_mpg
# 0       NaN       5.0         NaN
# 1   179 mph       5.0    13.7 mpg
# 2   155 mph       5.0    14.7 mpg
# 3       NaN       5.0         NaN
# 4       NaN       5.0         NaN

# %%
sorted_data = cd.sort_values('Reg_year', ascending=False)

# %%
sorted_data[['Maker','Reg_year']]
# Out:
#           Maker  Reg_year
# 513  Land Rover    2019.0
# 161     Bentley    2019.0
# 162     Bentley    2019.0
# 163     Bentley    2019.0
# 165     Bentley    2019.0
# ..          ...       ...
# 367     Bentley    1995.0
# 179     Bentley    1995.0
# 178     Bentley    1995.0
# 514         NaN       NaN
# 515         NaN       NaN
#
# [516 rows x 2 columns]

# %% [markdown]
# # **Categorising Data:**
#  Categorizing data means grouping data into different categories or classes based on some criteria. It helps organize information so it is easier to analyze or compare.
#
# Examples:
#
# Grouping rides as Short, Medium, Long based on distance.
#
# Grouping customers by Age: Child, Teen, Adult.
#
# Grouping Booking Value as Low, Medium, High.
#
# It turns raw data into meaningful groups to make analysis easier.
#
# # What this code does:-
# In my data set i categorize car's condition based on its runned miles:

# %%
cd['bins'] = pd.cut(x=cd['Runned_Miles'], bins=[10,47006,94003,141000],
                               labels = ['New', 'Mid', 'Old'])
# Out:
# /tmp/ipython-input-1085801447.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cd['bins'] = pd.cut(x=cd['Runned_Miles'], bins=[10,47006,94003,141000],

# %%
cd[['Runned_Miles','bins']].head()
# Out:
#    Runned_Miles bins
# 0       60000.0  Mid
# 1       44000.0  New
# 2       55000.0  Mid
# 3       14000.0  New
# 4       61652.0  Mid

# %% [markdown]
# # **Removing duplicates**
# The below function is used to remove the duplicates data from our rows.

# %%
marketing_data_duplicate = cd.drop_duplicates()
marketing_data_duplicate
# Out:
#           Maker  Reg_year  Adv_month   Color  Runned_Miles  Wheelbase  Length  \
# 0       Bentley    2000.0        4.0  Silver       60000.0     3116.0  5390.0
# 1       Bentley    2002.0        6.0    Grey       44000.0     3116.0  5390.0
# 2       Bentley    2002.0       11.0    Blue       55000.0     3116.0  5390.0
# 3       Bentley    2003.0        4.0   Green       14000.0     3116.0  5390.0
# 4       Bentley    2003.0       11.0    Grey       61652.0     3116.0  5390.0
# ..          ...       ...        ...     ...           ...        ...     ...
# 510  Land Rover    2019.0        6.0   Black       15287.0     2650.0  4490.0
# 511  Land Rover    2019.0        6.0     Red        8000.0     2650.0  4235.0
# 512  Land Rover    2019.0       10.0    Blue        8893.0     2650.0  4505.0
# 513  Land Rover    2019.0        4.0  Silver        6113.0     2650.0  4260.0
# 514         NaN       NaN        NaN     NaN           NaN        NaN     NaN
#
#     Top_speed  Seat_num Average_mpg bins
# 0         NaN       5.0         NaN  Mid
# 1     179 mph       5.0    13.7 mpg  New
# 2     155 mph       5.0    14.7 mpg  Mid
# 3         NaN       5.0         NaN  New
# 4         NaN       5.0         NaN  Mid
# ..        ...       ...         ...  ...
# 510   112 mph       5.0    48.7 mpg  New
# 511   106 mph       5.0         NaN  New
# 512   122 mph       5.0    67.3 mpg  New
# 513   117 mph       5.0    62.8 mpg  New
# 514       NaN       NaN         NaN  NaN
#
# [514 rows x 11 columns]

# %%
marketing_data_duplicate.shape
# Out:
# (514, 11)

# %% [markdown]
# # **Deleting or Droping Rows :**
# Dropping rows and columns means removing unwanted data from our dataset.
#
# Dropping rows means it deletes specific rows, usually based on index or condition.
#
# Example: removing cars without registration year.
#
# Dropping columns means deletes entire columns that are not needed.
#
# # **In the below code: **
#
# The function removes a column like Seat_num.

# %%
cd = data [['Maker','Reg_year',	'Adv_month','Color','Runned_Miles','Wheelbase','Length','Top_speed','Seat_num','Average_mpg']]
cd.head()
# Out:
#      Maker  Reg_year  Adv_month   Color  Runned_Miles  Wheelbase  Length  \
# 0  Bentley    2000.0        4.0  Silver       60000.0     3116.0  5390.0
# 1  Bentley    2002.0        6.0    Grey       44000.0     3116.0  5390.0
# 2  Bentley    2002.0       11.0    Blue       55000.0     3116.0  5390.0
# 3  Bentley    2003.0        4.0   Green       14000.0     3116.0  5390.0
# 4  Bentley    2003.0       11.0    Grey       61652.0     3116.0  5390.0
#
#   Top_speed  Seat_num Average_mpg
# 0       NaN       5.0         NaN
# 1   179 mph       5.0    13.7 mpg
# 2   155 mph       5.0    14.7 mpg
# 3       NaN       5.0         NaN
# 4       NaN       5.0         NaN

# %% [markdown]
# # **Deleting a specified rows at index values 1**

# %%
cd.drop(labels=[1], axis=0)
# Out:
#           Maker  Reg_year  Adv_month   Color  Runned_Miles  Wheelbase  Length  \
# 0       Bentley    2000.0        4.0  Silver       60000.0     3116.0  5390.0
# 2       Bentley    2002.0       11.0    Blue       55000.0     3116.0  5390.0
# 3       Bentley    2003.0        4.0   Green       14000.0     3116.0  5390.0
# 4       Bentley    2003.0       11.0    Grey       61652.0     3116.0  5390.0
# 5       Bentley    2002.0       12.0    Blue       55000.0     3116.0  5390.0
# ..          ...       ...        ...     ...           ...        ...     ...
# 511  Land Rover    2019.0        6.0     Red        8000.0     2650.0  4235.0
# 512  Land Rover    2019.0       10.0    Blue        8893.0     2650.0  4505.0
# 513  Land Rover    2019.0        4.0  Silver        6113.0     2650.0  4260.0
# 514         NaN       NaN        NaN     NaN           NaN        NaN     NaN
# 515         NaN       NaN        NaN     NaN           NaN        NaN     NaN
#
#     Top_speed  Seat_num Average_mpg
# 0         NaN       5.0         NaN
# 2     155 mph       5.0    14.7 mpg
# 3         NaN       5.0         NaN
# 4         NaN       5.0         NaN
# 5     179 mph       5.0    13.7 mpg
# ..        ...       ...         ...
# 511   106 mph       5.0         NaN
# 512   122 mph       5.0    67.3 mpg
# 513   117 mph       5.0    62.8 mpg
# 514       NaN       NaN         NaN
# 515       NaN       NaN         NaN
#
# [515 rows x 10 columns]

# %% [markdown]
# # **Deleting a single column :**
# In the below code,I removed Adv_month using drop function.

# %%
cd.drop(labels=['Adv_month'], axis=1)
# Out:
#           Maker  Reg_year   Color  Runned_Miles  Wheelbase  Length Top_speed  \
# 0       Bentley    2000.0  Silver       60000.0     3116.0  5390.0       NaN
# 1       Bentley    2002.0    Grey       44000.0     3116.0  5390.0   179 mph
# 2       Bentley    2002.0    Blue       55000.0     3116.0  5390.0   155 mph
# 3       Bentley    2003.0   Green       14000.0     3116.0  5390.0       NaN
# 4       Bentley    2003.0    Grey       61652.0     3116.0  5390.0       NaN
# ..          ...       ...     ...           ...        ...     ...       ...
# 511  Land Rover    2019.0     Red        8000.0     2650.0  4235.0   106 mph
# 512  Land Rover    2019.0    Blue        8893.0     2650.0  4505.0   122 mph
# 513  Land Rover    2019.0  Silver        6113.0     2650.0  4260.0   117 mph
# 514         NaN       NaN     NaN           NaN        NaN     NaN       NaN
# 515         NaN       NaN     NaN           NaN        NaN     NaN       NaN
#
#      Seat_num Average_mpg
# 0         5.0         NaN
# 1         5.0    13.7 mpg
# 2         5.0    14.7 mpg
# 3         5.0         NaN
# 4         5.0         NaN
# ..        ...         ...
# 511       5.0         NaN
# 512       5.0    67.3 mpg
# 513       5.0    62.8 mpg
# 514       NaN         NaN
# 515       NaN         NaN
#
# [516 rows x 9 columns]

# %% [markdown]
# # **Changing Data Format :-**
# In Changing data Format, we are converting the float into integer and we fill the missing values with fillna(0) and change its dtype into integer with astype(int)
#
# The below code fill NAN in the Booking Value column with 0(Zero).

# %% [markdown]
# # **Filling NAs in the Adv_month column**

# %%
cd['Adv_month'] = cd['Adv_month'].fillna(0)
# Out:
# /tmp/ipython-input-1933202160.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cd['Adv_month'] = cd['Adv_month'].fillna(0)

# %% [markdown]
# # **Changing the data type of the Income from float to int**

# %%
cd['Adv_month_changed'] = cd['Adv_month'].astype(int)
# Out:
# /tmp/ipython-input-2809782552.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cd['Adv_month_changed'] = cd['Adv_month'].astype(int)

# %%
cd[['Adv_month','Adv_month_changed']].head()
# Out:
#    Adv_month  Adv_month_changed
# 0        4.0                  4
# 1        6.0                  6
# 2       11.0                 11
# 3        4.0                  4
# 4       11.0                 11

# %%
cd[['Adv_month','Adv_month_changed']].dtypes
# Out:
# Adv_month            float64
# Adv_month_changed      int64
# dtype: object

# %% [markdown]
# # **Subset for relevant columns**

# %%
cars_data = data[['Maker','Reg_year','Color','Runned_Miles','Top_speed']]
cars_data.head(10)
# Out:
#      Maker  Reg_year   Color  Runned_Miles Top_speed
# 0  Bentley    2000.0  Silver       60000.0       NaN
# 1  Bentley    2002.0    Grey       44000.0   179 mph
# 2  Bentley    2002.0    Blue       55000.0   155 mph
# 3  Bentley    2003.0   Green       14000.0       NaN
# 4  Bentley    2003.0    Grey       61652.0       NaN
# 5  Bentley    2002.0    Blue       55000.0   179 mph
# 6  Bentley    2002.0   Green       67000.0   179 mph
# 7  Bentley    2003.0   Black       99200.0       NaN
# 8  Bentley    2003.0  Silver       27541.0       NaN
# 9  Bentley    2003.0  Silver       38000.0       NaN

# %%
cars_data.shape
# Out:
# (516, 5)

# %% [markdown]
# # **Replacing Data :**
# Replacing data means changing specific values in our dataset with new ones usually to fix errors or standardize information.
#
# For example:
#
# In my data set I change the Maker name to the new one that help us for better understanding.

# %%
cars_data['Maker_replaced'] = cd['Maker'].replace(['Bentley','Land Rover'],['Bently car','RangeRover']).copy()

cars_data[['Maker','Maker_replaced']].head()
# Out:
# /tmp/ipython-input-2658990983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars_data['Maker_replaced'] = cd['Maker'].replace(['Bentley','Land Rover'],['Bently car','RangeRover']).copy()
#      Maker Maker_replaced
# 0  Bentley     Bently car
# 1  Bentley     Bently car
# 2  Bentley     Bently car
# 3  Bentley     Bently car
# 4  Bentley     Bently car

# %% [markdown]
# # **Checking for missing values**
# By using below function,we found out the missing values in colums in the relevent subset values.

# %%
cars_data.isnull().sum()
# Out:
# Maker               2
# Reg_year            2
# Color              23
# Runned_Miles        4
# Top_speed         275
# Maker_replaced      2
# dtype: int64

# %% [markdown]
# # **Droping Missing values**
# By using below function,we removed the missing values colums in the relevent subset values.

# %%
cars_data_withoutna = cars_data.dropna(how = 'any')
cars_data_withoutna.head()
# Out:
#       Maker  Reg_year   Color  Runned_Miles Top_speed Maker_replaced
# 1   Bentley    2002.0    Grey       44000.0   179 mph     Bently car
# 2   Bentley    2002.0    Blue       55000.0   155 mph     Bently car
# 5   Bentley    2002.0    Blue       55000.0   179 mph     Bently car
# 6   Bentley    2002.0   Green       67000.0   179 mph     Bently car
# 11  Bentley    2002.0  Silver       52000.0   179 mph     Bently car

# %%
cars_data_withoutna.shape
# Out:
# (231, 6)
